# %%
w1 = 'BIERGARTEN'
w2 = 'STERNWARTE'

# %%
import math
import numpy as np

def needleman(w1,w2,match=1,mismatch=0,skip=-1):
    storage = np.full((len(w1)+1,len(w2)+1),None)
    paths = np.full((len(w1)+1,len(w2)+1),None)
    storage[0,0] = 0
    def nm(i,j):
        if i<0 or j<0:
            return -math.inf
        if storage[i,j] is not None:
            return storage[i,j]
        left = nm(i-1,j) + skip
        up = nm(i,j-1) + skip
        diag = nm(i-1,j-1) + match if w1[i-1]==w2[j-1] else mismatch
        scores = [left,diag,up]
        print(scores)
#         argsorted = np.argmax(scores)
        storage[i,j] = scores[argsorted]
#         paths[i,j] = ['L','D','U'][scores == scores[argsorted[0]]]
        return storage[i,j]
    
    nm(len(w1),len(w2))
    return storage.astype('int'), paths

# %%
needleman(w1,w2)
# Out:
# [-inf, 0, -1]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-1ae11a46fb2f> in <module>
# ----> 1 needleman(w1,w2)
#
# <ipython-input-72-f8f4857f8645> in needleman(w1, w2, match, mismatch, skip)
#      21         return storage[i,j]
#      22
# ---> 23     nm(len(w1),len(w2))
#      24     return storage.astype('int'), paths
#
# <ipython-input-72-f8f4857f8645> in nm(i, j)
#      11         if storage[i,j] is not None:
#      12             return storage[i,j]
# ---> 13         left = nm(i-1,j) + skip
#      14         up = nm(i,j-1) + skip
#      15         diag = nm(i-1,j-1) + match if w1[i-1]==w2[j-1] else mismatch
#
# <ipython-input-72-f8f4857f8645> in nm(i, j)
#      11         if storage[i,j] is not None:
#      12             return storage[i,j]
# ---> 13         left = nm(i-1,j) + skip
#      14         up = nm(i,j-1) + skip
# ...

# %%
# Out:
# array([[None, None, None, None, None],
#        [None, None, None, None, None],
#        [None, None, None, None, None],
#        [None, None, None, None, None],
#        [None, None, None, None, None]], dtype=object)
